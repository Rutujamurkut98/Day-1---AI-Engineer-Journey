# %% [markdown]
# # Getting Started with Python Programming Language

# %% [markdown]
# ## Day-1 AI Engineer Journey

# %%
# What is Python Programming?
'''Python is a high-level, interpreted, general-purpose programming language 
that is simple, open-source, platform-independent, and dynamically typed.
It supports multiple programming paradigms, including object-oriented and functional programming, 
and is widely used in Artificial Intelligence, Data Science, Machine Learning, Web Development, 
and Automation due to its extensive library support and flexibility'''

# %% [markdown]
# ### Features of PYTHON Programming Language

# %%
The PYTHON Programming Lang Provides 11 Features. They are :
			1. Simple
			2. Freeware and Open Source
			3. Platform Independent
			4. Dynamically Typed 
			5. Interpreted 
			6. High Level
			7. Robust (Strong)
			8. Extensible
			9. Embedded 
			10. Supports Third Party  API 
			11. Functional and Object Oriented

# %% [markdown]
# #### What is Program

# %%
=> A Program is a Collection of OPTIMIZED Instructions Meant for Performing Certain Operation / Task.
=> OPTIMIZED Instructions are nothing but The Program Must Takes Less Time Complexity and Less Space complexity.

# %% [markdown]
# #### What is Programming?

# %%
=> Programming is the process of designing, writing, testing, and maintaining
   instructions (code) that a computer can execute to solve a problem.

# %%
print("Helloo Welcome to my Profile")
# Out:
# Helloo Welcome to my Profile

# %%
print("Hello World...!!!")
# Out:
# Hello World...!!!

# %%
print("Python is Functional and Object-Oriented Programming Language")
# Out:
# Python is Functional and Object-Oriented Programming Language

# %%
print("""The more you Learn,
The more you Earn""")
# Out:
# The more you Learn,
# The more you Earn

# %% [markdown]
# #### Literals in Python

# %%
=> In Any Programming Language, Literals Must be Stored in Main Memory by allocating Sufficient
Amount of Memory space with the Help Of Data Types
=> Literals are fixed values that are directly assigned to variables in a program.
They represent constant data stored in memory.

# %% [markdown]
# #### Types of Literals

# %%
Fundamentally, we have 5 types of Literals OR Values. They are
		    1. Integer Literals
			2. String Literals
			3. Float Literals
			4. Boolean Literals
			5. Collection Literals

# %% [markdown]
# #### Variable

# %%
A Variable is an Identifier whose Value can be changed during Program Execution.

# %% [markdown]
# #### Rules for Using the Variables  OR  Identifiers

# %% [markdown]
# #### Rule-1 The Variable Name is a Combination of Alphabets, Digits and Special Symbol Called Under                      Score ( _ ).

# %%
name="Rutuja"
print(name)
# Out:
# Rutuja

# %%
age=22
print(age)
# Out:
# 22

# %%
Institute_name="Naresh i technologies"
print(Institute_name)
# Out:
# Naresh i technologies

# %%
stdid_107="Student id 107"
print(stdid_107)
# Out:
# Student id 107

# %%
_marks=155
print(_marks)
# Out:
# 155

# %%
_123="9834....."
print(_123)
# Out:
# 9834.....

# %% [markdown]
# #### Rule-2 The First Letter of Variable Name Must Starts Either with Alphabet OR Special Symbol Under Score ( _ ).

# %%
Salary="10 lakh"
print("Salary Expection Minimum =",Salary)
# Out:
# Salary Expection Minimum = 10 lakh

# %%
_Location="Hyderabad"
print(_Location)
# Out:
# Hyderabad

# %%
std_age=21
print(std_age)
# Out:
# 21

# %%
std_id=103
print(std_id)
# Out:
# 103

# %% [markdown]
# #### Rule-3  Within the Variable Name, No special Symbols are allowed except under score ( _ ).

# %%
# Only (_) Under Score as a special Symbol allowed
_name=("Rutuja......!!")
print(_name)
# Out:
# Rutuja......!!

# %% [markdown]
# #### Rule-4	 No Keywords to be used  as Variable Names (Keyword is one of the Reserved Word and It
# #### gives Special Meaning to the Lang  Compilers/Interpreters)

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print("Total Keywords :",len(keyword.kwlist))
# Out:
# Total Keywords : 35

# %%
print("Total Soft keywords :",keyword.softkwlist)
# Out:
# Total Soft keywords : ['_', 'case', 'match', 'type']

# %%
print("Total softkeyword :",len(keyword.softkwlist))
# Out:
# Total softkeyword : 4

# %%
if_value = 10   #Valid

# %%
while_count = 5   #Valid

# %%
while = 5    #invalid

# %%
class = "AI"  #invalid

# %% [markdown]
# #### Rule-5	 All Variable Names in Python are Case Sensitive.

# %%
age = 25
Age = 30
AGE = 35
aGe = 96

print(age)  # 25
print(Age)  # 30
print(AGE)  # 35
print(aGe)  #96
# Out:
# 25
# 30
# 35
# 96

# %% [markdown]
# #### Rule-6: Variable Names Cannot Contain Spaces

# %%
student age = 20         #Invalid 
total marks = 100        #Invalid 
my name = "Rutuja"       #Invalid

# %%
student_age = 20         #Valid
total_marks = 100        #Valid
my_name = "Rutuja"       #Valid

print(student_age)  # 20
print(total_marks)  # 100
print(my_name)      # Rutuja
# Out:
# 20
# 100
# Rutuja
